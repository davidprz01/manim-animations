# %%
from manim import *

# %% [markdown]
# ## Verificar instalación

# %%
# %%manim -qm -v Warning TestScene
#
# class TestScene(Scene):
#     def construct(self):
#         text = Text("¡Manim instalado correctamente!", color=BLUE)
#         self.play(Write(text))
#         self.wait(2)
